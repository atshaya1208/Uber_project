# %% [markdown]
# <a href="https://colab.research.google.com/github/atshaya1208/Uber_project/blob/main/Uber_eats_project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import ast

# %%
data = pd.read_csv("/content/Uber_Eats_data.csv")

# %%
data.shape
# Out:
# (23193, 13)

# %%
data.head()
# Out:
#                     name online_order book_table   rate  votes  \
# 0                  Jalsa          Yes        Yes  4.1/5    775
# 1         Spice Elephant          Yes         No  4.1/5    787
# 2        San Churro Cafe          Yes         No  3.8/5    918
# 3  Addhuri Udupi Bhojana           No         No  3.7/5     88
# 4          Grand Village           No         No  3.8/5    166
#
#                               phone      location            rest_type  \
# 0    080 42297555\r\n+91 9743772233  Banashankari        Casual Dining
# 1                      080 41714161  Banashankari        Casual Dining
# 2                    +91 9663487993  Banashankari  Cafe, Casual Dining
# 3                    +91 9620009302  Banashankari          Quick Bites
# 4  +91 8026612447\r\n+91 9901210005  Basavanagudi        Casual Dining
#
#                                           dish_liked  \
# 0  Pasta, Lunch Buffet, Masala Papad, Paneer Laja...
# ...

# %%
data.columns
# Out:
# Index(['name', 'online_order', 'book_table', 'rate', 'votes', 'phone',
#        'location', 'rest_type', 'dish_liked', 'cuisines',
#        'approx_cost(for two people)', 'listed_in(type)', 'listed_in(city)'],
#       dtype='object')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23193 entries, 0 to 23192
# Data columns (total 13 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   name                         23193 non-null  object
#  1   online_order                 23193 non-null  object
#  2   book_table                   23193 non-null  object
#  3   rate                         23193 non-null  object
#  4   votes                        23193 non-null  int64
#  5   phone                        23193 non-null  object
#  6   location                     23193 non-null  object
#  7   rest_type                    23193 non-null  object
#  8   dish_liked                   23193 non-null  object
#  9   cuisines                     23193 non-null  object
#  10  approx_cost(for two people)  23193 non-null  object
#  11  listed_in(type)              23193 non-null  object
#  12  listed_in(city)              23193 non-null  object
# ...

# %% [markdown]
# NAME

# %%
data['name']
# Out:
# 0                                                    Jalsa
# 1                                           Spice Elephant
# 2                                          San Churro Cafe
# 3                                    Addhuri Udupi Bhojana
# 4                                            Grand Village
#                                ...
# 23188                                   Izakaya Gastro Pub
# 23189          M Bar - Bengaluru Marriott Hotel Whitefield
# 23190                               Keys Cafe - Keys Hotel
# 23191                                              Bhagini
# 23192    Chime - Sheraton Grand Bengaluru Whitefield Ho...
# Name: name, Length: 23193, dtype: object

# %%
data['name'].values[0]
# Out:
# 'Jalsa'

# %%
data["name"].isnull().sum()
# Out:
# np.int64(0)

# %%
data.name = data.name.str.lower()
data.name = data.name.str.strip()
data.name
# Out:
# 0                                                    jalsa
# 1                                           spice elephant
# 2                                          san churro cafe
# 3                                    addhuri udupi bhojana
# 4                                            grand village
#                                ...
# 23188                                   izakaya gastro pub
# 23189          m bar - bengaluru marriott hotel whitefield
# 23190                               keys cafe - keys hotel
# 23191                                              bhagini
# 23192    chime - sheraton grand bengaluru whitefield ho...
# Name: name, Length: 23193, dtype: object

# %%
data[data.duplicated()]
# Out:
#                                                    name online_order  \
# 1532                              the fisherman's wharf          Yes
# 1998                                          opus club           No
# 1999                                              float          Yes
# 2015                                              float          Yes
# 2887                                               fava           No
# 4243                                            vyanjan          Yes
# 4244                                  mid night hunting          Yes
# 4245                                            carrots          Yes
# 4246                                         rolls & co          Yes
# 4973                         fenny's lounge and kitchen           No
# 5401                           laughing llama gastropub          Yes
# 5402                                     the bundle co.          Yes
# 5410   moto store & cafãâãâãâãâãâãâãâãâ©          Yes
# ...

# %%
data.duplicated().sum()
# Out:
# np.int64(35)

# %%
data = data.drop_duplicates(keep = 'last')

# %%
data.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ONLINE ORDER

# %%
data['online_order']
# Out:
# 0        Yes
# 1        Yes
# 2        Yes
# 3         No
# 4         No
#         ...
# 23188    Yes
# 23189     No
# 23190     No
# 23191     No
# 23192     No
# Name: online_order, Length: 23158, dtype: object

# %%
data['online_order'].values[0]
# Out:
# 'Yes'

# %%
data.online_order.values
# Out:
# array(['Yes', 'Yes', 'Yes', ..., 'No', 'No', 'No'], dtype=object)

# %%
data['online_order'].value_counts()
# Out:
# online_order
# Yes    16335
# No      6823
# Name: count, dtype: int64

# %%
data['online_order'] = data['online_order'].str.lower()
data['online_order'] = data['online_order'].str.strip()
data['online_order']
# Out:
# 0        yes
# 1        yes
# 2        yes
# 3         no
# 4         no
#         ...
# 23188    yes
# 23189     no
# 23190     no
# 23191     no
# 23192     no
# Name: online_order, Length: 23158, dtype: object

# %%
data['online_order'].isnull().sum()
# Out:
# np.int64(0)

# %%
data
# Out:
#                                                     name online_order  \
# 0                                                  jalsa          yes
# 1                                         spice elephant          yes
# 2                                        san churro cafe          yes
# 3                                  addhuri udupi bhojana           no
# 4                                          grand village           no
# ...                                                  ...          ...
# 23188                                 izakaya gastro pub          yes
# 23189        m bar - bengaluru marriott hotel whitefield           no
# 23190                             keys cafe - keys hotel           no
# 23191                                            bhagini           no
# 23192  chime - sheraton grand bengaluru whitefield ho...           no
#
#       book_table    rate  votes                             phone  \
# ...

# %% [markdown]
# BOOK TABLE

# %%
data['book_table']
# Out:
# 0        Yes
# 1         No
# 2         No
# 3         No
# 4         No
#         ...
# 23188    Yes
# 23189     No
# 23190     No
# 23191     No
# 23192    Yes
# Name: book_table, Length: 23158, dtype: object

# %%
data['book_table'].values
# Out:
# array(['Yes', 'No', 'No', ..., 'No', 'No', 'Yes'], dtype=object)

# %%
data['book_table'].value_counts()
# Out:
# book_table
# No     17057
# Yes     6101
# Name: count, dtype: int64

# %%
data['book_table'] = data['book_table'].str.lower()
data['book_table'] = data['book_table'].str.strip()
data['book_table']
# Out:
# 0        yes
# 1         no
# 2         no
# 3         no
# 4         no
#         ...
# 23188    yes
# 23189     no
# 23190     no
# 23191     no
# 23192    yes
# Name: book_table, Length: 23158, dtype: object

# %%
data['book_table'].isnull().sum()
# Out:
# np.int64(0)

# %% [markdown]
# RATINGS

# %%
data['rate'].values[0]
# Out:
# '4.1/5'

# %%
data.rate.dtype
# Out:
# dtype('O')

# %%
data.rate.value_counts()
# Out:
# rate
# 3.9/5     1686
# 3.9 /5    1547
# 4.0/5     1467
# 4.1/5     1396
# 4.0 /5    1390
#           ...
# 2.2 /5       7
# 2.0 /5       7
# 2.0/5        4
# 1.8 /5       3
# 1.8/5        2
# Name: count, Length: 63, dtype: int64

# %%
data.rate.isnull().sum()
# Out:
# np.int64(0)

# %%
ratings = []
for i in data['rate']:
  if i == 'NEW' or i == '-':
    ratings.append(np.nan)
  else:
    i = str(i).split('/')[0]
    ratings.append(i)
data['rate'] = ratings

# %%
data['rate'].value_counts()
# Out:
# rate
# 3.9     1686
# 3.9     1547
# 4.0     1467
# 4.1     1396
# 4.0     1390
#         ...
# 2.2        7
# 2.0        7
# 2.0        4
# 1.8        3
# 1.8        2
# Name: count, Length: 62, dtype: int64

# %%
data.rate.isnull().sum()
# Out:
# np.int64(146)

# %%
data = data.dropna(subset=['rate'])

# %%
data.rate.isnull().sum()
# Out:
# np.int64(0)

# %%
data['rate'] = data['rate'].astype(float)
# Out:
# /tmp/ipykernel_6159/1957175498.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['rate'] = data['rate'].astype(float)

# %%
data['rate'].dtype
# Out:
# dtype('float64')

# %%
data.rate.describe()
# Out:
# count    23012.000000
# mean         3.904002
# std          0.426388
# min          1.800000
# 25%          3.800000
# 50%          4.000000
# 75%          4.200000
# max          4.900000
# Name: rate, dtype: float64

# %% [markdown]
# VOTE

# %%
data.votes
# Out:
# 0        775
# 1        787
# 2        918
# 3         88
# 4        166
#         ...
# 23188    128
# 23189     77
# 23190    161
# 23191     81
# 23192    236
# Name: votes, Length: 23012, dtype: int64

# %%
data['votes'].values[0]
# Out:
# np.int64(775)

# %%
data.votes.isnull().sum()
# Out:
# np.int64(0)

# %%
data['votes'].value_counts()
# Out:
# votes
# 61      140
# 53      136
# 46      126
# 48      115
# 74      112
#        ...
# 3730      1
# 2749      1
# 2292      1
# 1359      1
# 2034      1
# Name: count, Length: 2283, dtype: int64

# %%
data.votes.dtype
# Out:
# dtype('int64')

# %%
data.votes.describe()
# Out:
# count    23012.000000
# mean       604.098688
# std       1116.738081
# min          0.000000
# 25%        103.000000
# 50%        224.000000
# 75%        590.000000
# max      16832.000000
# Name: votes, dtype: float64

# %% [markdown]
# PHONE NUMBER

# %%
data.phone
# Out:
# 0          080 42297555\r\n+91 9743772233
# 1                            080 41714161
# 2                          +91 9663487993
# 3                          +91 9620009302
# 4        +91 8026612447\r\n+91 9901210005
#                        ...
# 23188      +91 7625087121\n+91 8050587483
# 23189                        080 49435000
# 23190        080 39451000\n+91 8884038484
# 23191                        080 65951222
# 23192                        080 49652769
# Name: phone, Length: 23012, dtype: object

# %%
data.phone.values[0]
# Out:
# '080 42297555\r\n+91 9743772233'

# %%
data.phone.isnull().sum()
# Out:
# np.int64(0)

# %%
data['phone'] = data['phone'].str.replace('\r\n',',')
data['phone'] = data['phone'].str.strip()
data['phone']
# Out:
# /tmp/ipykernel_6159/1947024104.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['phone'] = data['phone'].str.replace('\r\n',',')
# /tmp/ipykernel_6159/1947024104.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['phone'] = data['phone'].str.strip()
# 0           080 42297555,+91 9743772233
# 1                          080 41714161
# 2                        +91 9663487993
# 3                        +91 9620009302
# 4         +91 8026612447,+91 9901210005
# ...

# %% [markdown]
# LOCATION

# %%
data.location
# Out:
# 0                      Banashankari
# 1                      Banashankari
# 2                      Banashankari
# 3                      Banashankari
# 4                      Basavanagudi
#                     ...
# 23188                    Whitefield
# 23189                    Whitefield
# 23190                    Whitefield
# 23191                    Whitefield
# 23192    ITPL Main Road, Whitefield
# Name: location, Length: 23012, dtype: object

# %%
data.location.values[0]
# Out:
# 'Banashankari'

# %%
data.location.value_counts()
# Out:
# location
# Koramangala 5th Block    1759
# BTM                      1444
# Indiranagar              1331
# HSR                      1154
# Jayanagar                1030
#                          ...
# Kanakapura Road             2
# West Bangalore              2
# Yelahanka                   2
# Magadi Road                 2
# KR Puram                    1
# Name: count, Length: 88, dtype: int64

# %%
data.location.isnull().sum()
# Out:
# np.int64(0)

# %%
data.location = data.location.str.lower()
data.location = data.location.str.strip()
data.location
# Out:
# /tmp/ipykernel_6159/1752838122.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.location = data.location.str.lower()
# /tmp/ipykernel_6159/1752838122.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.location = data.location.str.strip()
# 0                      banashankari
# 1                      banashankari
# 2                      banashankari
# 3                      banashankari
# 4                      basavanagudi
#                     ...
# ...

# %% [markdown]
# REST TYPE

# %%
data.rest_type
# Out:
# 0              Casual Dining
# 1              Casual Dining
# 2        Cafe, Casual Dining
# 3                Quick Bites
# 4              Casual Dining
#                 ...
# 23188     Bar, Casual Dining
# 23189       Fine Dining, Bar
# 23190     Casual Dining, Bar
# 23191     Casual Dining, Bar
# 23192                    Bar
# Name: rest_type, Length: 23012, dtype: object

# %%
data.rest_type.values[0]
# Out:
# 'Casual Dining'

# %%
data.rest_type.value_counts()
# Out:
# rest_type
# Casual Dining                7291
# Quick Bites                  5219
# Cafe                         2319
# Dessert Parlor               1073
# Casual Dining, Bar            975
#                              ...
# Fine Dining, Microbrewery       5
# Club, Casual Dining             4
# Dessert Parlor, Kiosk           2
# Dhaba                           1
# Food Court, Casual Dining       1
# Name: count, Length: 73, dtype: int64

# %%
data.rest_type.isnull().sum()
# Out:
# np.int64(0)

# %%
data.rest_type = data.rest_type.str.lower()
data.rest_type = data.rest_type.str.strip()
data.rest_type
# Out:
# /tmp/ipykernel_6159/562940965.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.rest_type = data.rest_type.str.lower()
# /tmp/ipykernel_6159/562940965.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.rest_type = data.rest_type.str.strip()
# 0              casual dining
# 1              casual dining
# 2        cafe, casual dining
# 3                quick bites
# 4              casual dining
#                 ...
# 23188     bar, casual dining
# 23189       fine dining, bar
# ...

# %% [markdown]
# DISH LIKED

# %%
data.dish_liked
# Out:
# 0        Pasta, Lunch Buffet, Masala Papad, Paneer Laja...
# 1        Momos, Lunch Buffet, Chocolate Nirvana, Thai G...
# 2        Churros, Cannelloni, Minestrone Soup, Hot Choc...
# 3                                              Masala Dosa
# 4                                      Panipuri, Gol Gappe
#                                ...
# 23188    Beer, Chicken Guntur, Paneer Tikka, Fish, Nood...
# 23189                                     Rooftop Ambience
# 23190    Salads, Coffee, Breakfast Buffet, Halwa, Chick...
# 23191                                 Biryani, Andhra Meal
# 23192                         Cocktails, Pizza, Buttermilk
# Name: dish_liked, Length: 23012, dtype: object

# %%
data.dish_liked.values[0]
# Out:
# 'Pasta, Lunch Buffet, Masala Papad, Paneer Lajawab, Tomato Shorba, Dum Biryani, Sweet Corn Soup'

# %%
data['dish_liked'].value_counts()
# Out:
# dish_liked
# Biryani                                                                                             179
# Friendly Staff                                                                                       68
# Waffles                                                                                              67
# Chicken Biryani                                                                                      66
# Masala Dosa                                                                                          56
#                                                                                                    ...
# Pasta, Creme Brulee, Tiramisu, Bbq Chicken Pizza, Steak, Salads, Wine                                 1
# Cocktails, Panna Cotta, Lamb Pizza, Pita Bread                                                        1
# Murgh Platter, Dessert Platter, Chicken Sizzler, Tiramisu, Lobster, Mocktails, Vegetable Biryani      1
# ...

# %%
data.dish_liked.isnull().sum()
# Out:
# np.int64(0)

# %%
data.dish_liked = data.dish_liked.str.lower()
data.dish_liked = data.dish_liked.str.strip()
data.dish_liked
# Out:
# /tmp/ipykernel_6159/577090098.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.dish_liked = data.dish_liked.str.lower()
# /tmp/ipykernel_6159/577090098.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.dish_liked = data.dish_liked.str.strip()
# 0        pasta, lunch buffet, masala papad, paneer laja...
# 1        momos, lunch buffet, chocolate nirvana, thai g...
# 2        churros, cannelloni, minestrone soup, hot choc...
# ...

# %% [markdown]
# CUISINES

# %%
data.cuisines
# Out:
# 0                     North Indian, Mughlai, Chinese
# 1                        Chinese, North Indian, Thai
# 2                             Cafe, Mexican, Italian
# 3                         South Indian, North Indian
# 4                           North Indian, Rajasthani
#                             ...
# 23188       North Indian, Continental, Mediterranean
# 23189                                    Finger Food
# 23190             Chinese, Continental, North Indian
# 23191    Andhra, South Indian, Chinese, North Indian
# 23192                                    Finger Food
# Name: cuisines, Length: 23012, dtype: object

# %%
data.cuisines.values[0]
# Out:
# 'North Indian, Mughlai, Chinese'

# %%
data.cuisines.value_counts()
# Out:
# cuisines
# North Indian                           1136
# North Indian, Chinese                   776
# South Indian                            359
# Cafe                                    273
# South Indian, North Indian, Chinese     233
#                                        ...
# Tibetan, Nepalese                         1
# South Indian, Chettinad                   1
# Andhra, Hyderabadi, Biryani               1
# Andhra, North Indian, South Indian        1
# Thai, Chinese, Momos                      1
# Name: count, Length: 1677, dtype: int64

# %%
data.cuisines.isnull().sum()
# Out:
# np.int64(0)

# %%
data.cuisines = data.cuisines.str.lower()
data.cuisines = data.cuisines.str.strip()
data.cuisines
# Out:
# /tmp/ipykernel_6159/3695237108.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.cuisines = data.cuisines.str.lower()
# /tmp/ipykernel_6159/3695237108.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.cuisines = data.cuisines.str.strip()
# 0                     north indian, mughlai, chinese
# 1                        chinese, north indian, thai
# 2                             cafe, mexican, italian
# 3                         south indian, north indian
# ...

# %% [markdown]
# AMOUNT FOR TWO PEOPLE

# %%
data['approx_cost(for two people)']
# Out:
# 0          800
# 1          800
# 2          800
# 3          300
# 4          600
#          ...
# 23188    1,200
# 23189    2,000
# 23190    1,200
# 23191      800
# 23192    2,500
# Name: approx_cost(for two people), Length: 23012, dtype: object

# %%
data['approx_cost(for two people)'].values[0]
# Out:
# '800'

# %%
data['approx_cost(for two people)'].value_counts()
# Out:
# approx_cost(for two people)
# 400      2458
# 500      2268
# 600      2163
# 300      1680
# 800      1641
# 1,000    1218
# 700      1154
# 1,200     894
# 200       857
# 1,500     829
# 450       718
# 250       692
# 750       652
# 650       636
# 350       553
# 900       513
# 1,300     494
# 1,100     444
# 550       439
# 1,400     437
# 150       366
# 2,000     294
# 1,600     235
# 1,700     229
# 1,800     189
# 3,000     159
# 2,500     142
# 850       122
# 100       117
# 2,100      60
# 1,900      57
# 950        47
# 2,200      39
# 2,800      31
# 3,500      25
# 4,000      24
# 2,400      22
# 1,350      18
# 180        17
# 3,400      13
# 230        10
# 40          8
# 1,250       8
# 1,650       6
# 1,450       5
# 330         4
# 4,100       4
# 2,600       4
# 1,050       4
# 3,200       2
# 6,000       2
# 2,700       2
# 120         2
# 4,500       2
# 2,300       1
# 5,000       1
# 3,700       1
# Name: count, dtype: int64

# %%
data['approx_cost(for two people)'].isnull().sum()
# Out:
# np.int64(0)

# %%
import ast
data['approx_cost(for two people)'] = data['approx_cost(for two people)'].str.replace(',','')
data['approx_cost(for two people)'] = data['approx_cost(for two people)'].astype('int')
data['approx_cost(for two people)']
# Out:
# /tmp/ipykernel_6159/2218977212.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['approx_cost(for two people)'] = data['approx_cost(for two people)'].str.replace(',','')
# /tmp/ipykernel_6159/2218977212.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['approx_cost(for two people)'] = data['approx_cost(for two people)'].astype('int')
# 0         800
# 1         800
# 2         800
# 3         300
# 4         600
#          ...
# 23188    1200
# 23189    2000
# 23190    1200
# ...

# %%
data['approx_cost(for two people)'].dtype
# Out:
# dtype('int64')

# %%
data['approx_cost(for two people)'].describe()
# Out:
# count    23012.000000
# mean       753.704154
# std        521.191287
# min         40.000000
# 25%        400.000000
# 50%        600.000000
# 75%       1000.000000
# max       6000.000000
# Name: approx_cost(for two people), dtype: float64

# %%
data.rename(columns={'approx_cost(for two people)':'cost_for_two_people'},inplace=True)
# Out:
# /tmp/ipykernel_6159/4117708203.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.rename(columns={'approx_cost(for two people)':'cost_for_two_people'},inplace=True)

# %%
data.shape
# Out:
# (23012, 13)

# %% [markdown]
# TYPES OF RESTAURANT

# %%
data['listed_in(type)']
# Out:
# 0               Buffet
# 1               Buffet
# 2               Buffet
# 3               Buffet
# 4               Buffet
#              ...
# 23188    Pubs and bars
# 23189    Pubs and bars
# 23190    Pubs and bars
# 23191    Pubs and bars
# 23192    Pubs and bars
# Name: listed_in(type), Length: 23012, dtype: object

# %%
data['listed_in(type)'].values[0]
# Out:
# 'Buffet'

# %%
data['listed_in(type)'].value_counts()
# Out:
# listed_in(type)
# Delivery              10559
# Dine-out               7947
# Desserts               1330
# Cafes                  1046
# Drinks & nightlife      864
# Buffet                  751
# Pubs and bars           515
# Name: count, dtype: int64

# %%
data['listed_in(type)'].isnull().sum()
# Out:
# np.int64(0)

# %%
data['listed_in(type)'] = data['listed_in(type)'].str.lower()
data['listed_in(type)'] = data['listed_in(type)'].str.strip()
data['listed_in(type)']
# Out:
# /tmp/ipykernel_6159/2327586653.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['listed_in(type)'] = data['listed_in(type)'].str.lower()
# /tmp/ipykernel_6159/2327586653.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['listed_in(type)'] = data['listed_in(type)'].str.strip()
# 0               buffet
# 1               buffet
# 2               buffet
# 3               buffet
# 4               buffet
#              ...
# 23188    pubs and bars
# 23189    pubs and bars
# ...

# %%
data.rename(columns={'listed_in(type)':'type_of_restaurant'},inplace=True)
# Out:
# /tmp/ipykernel_6159/691982855.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.rename(columns={'listed_in(type)':'type_of_restaurant'},inplace=True)

# %% [markdown]
# CITY

# %%
data['listed_in(city)']
# Out:
# 0        Banashankari
# 1        Banashankari
# 2        Banashankari
# 3        Banashankari
# 4        Banashankari
#              ...
# 23188      Whitefield
# 23189      Whitefield
# 23190      Whitefield
# 23191      Whitefield
# 23192      Whitefield
# Name: listed_in(city), Length: 23012, dtype: object

# %%
data['listed_in(city)'].values[0]
# Out:
# 'Banashankari'

# %%
data['listed_in(city)'].value_counts()
# Out:
# listed_in(city)
# BTM                      1399
# Koramangala 7th Block    1357
# Koramangala 4th Block    1331
# Koramangala 5th Block    1291
# Koramangala 6th Block    1237
# Jayanagar                1040
# Indiranagar              1010
# MG Road                  1003
# Church Street             973
# Brigade Road              963
# Lavelle Road              893
# Residency Road            839
# JP Nagar                  809
# Old Airport Road          743
# HSR                       729
# Whitefield                627
# Marathahalli              618
# Brookefield               595
# Basavanagudi              594
# Frazer Town               544
# Bannerghatta Road         540
# Kammanahalli              530
# Kalyan Nagar              515
# Bellandur                 497
# Sarjapur Road             496
# Malleshwaram              492
# Rajajinagar               374
# Banashankari              372
# Electronic City           319
# New BEL Road              282
# ...

# %%
data = data.drop(columns = ['listed_in(city)'])

# %%
data.head()
# Out:
#                     name online_order book_table  rate  votes  \
# 0                  jalsa          yes        yes   4.1    775
# 1         spice elephant          yes         no   4.1    787
# 2        san churro cafe          yes         no   3.8    918
# 3  addhuri udupi bhojana           no         no   3.7     88
# 4          grand village           no         no   3.8    166
#
#                            phone      location            rest_type  \
# 0    080 42297555,+91 9743772233  banashankari        casual dining
# 1                   080 41714161  banashankari        casual dining
# 2                 +91 9663487993  banashankari  cafe, casual dining
# 3                 +91 9620009302  banashankari          quick bites
# 4  +91 8026612447,+91 9901210005  basavanagudi        casual dining
#
#                                           dish_liked  \
# 0  pasta, lunch buffet, masala papad, paneer laja...
# 1  momos, lunch buffet, chocolate nirvana, thai g...
# ...

# %%
data['name'] = data['name'].str.replace(r'[^a-zA-Z0-9 ]', '', regex=True)

# %%
data.duplicated().sum()
# Out:
# np.int64(5025)

# %%
data = data.drop_duplicates(keep = 'last')

# %%
data.duplicated().sum()
# Out:
# np.int64(0)

# %%
data.head()
# Out:
#                      name online_order book_table  rate  votes  \
# 1          spice elephant          yes         no   4.1    787
# 3   addhuri udupi bhojana           no         no   3.7     88
# 6                  onesta          yes        yes   4.6   2556
# 9      caf down the alley          yes         no   4.1    402
# 11       the coffee shack          yes        yes   4.2    164
#
#                           phone      location            rest_type  \
# 1                  080 41714161  banashankari        casual dining
# 3                +91 9620009302  banashankari          quick bites
# 6     080 48653961,080 48655715  banashankari  casual dining, cafe
# 9   080 26724489,+91 7406048982  banashankari                 cafe
# 11               +91 9731644212  banashankari                 cafe
#
#                                            dish_liked  \
# 1   momos, lunch buffet, chocolate nirvana, thai g...
# 3                                         masala dosa
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 17987 entries, 1 to 23192
# Data columns (total 12 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   name                 17987 non-null  object
#  1   online_order         17987 non-null  object
#  2   book_table           17987 non-null  object
#  3   rate                 17987 non-null  float64
#  4   votes                17987 non-null  int64
#  5   phone                17987 non-null  object
#  6   location             17987 non-null  object
#  7   rest_type            17987 non-null  object
#  8   dish_liked           17987 non-null  object
#  9   cuisines             17987 non-null  object
#  10  cost_for_two_people  17987 non-null  int64
#  11  type_of_restaurant   17987 non-null  object
# dtypes: float64(1), int64(2), object(9)
# memory usage: 1.8+ MB

# %%
data.shape
# Out:
# (17987, 12)

# %%
data.columns
# Out:
# Index(['name', 'online_order', 'book_table', 'rate', 'votes', 'phone',
#        'location', 'rest_type', 'dish_liked', 'cuisines',
#        'cost_for_two_people', 'type_of_restaurant'],
#       dtype='object')

# %%
Uber_Eats_data = data.to_csv('uber_cleaned_data.csv', index=False)

# %% [markdown]
# ORDERS DATA

# %%
df = pd.read_json('/content/orders.json')

# %%
df.head()
# Out:
#                                order_id          restaurant_name  order_date  \
# 0  8174c2af-07a4-4837-9068-1169d963e36e           TBC Sky Lounge  2025-05-06
# 1  0f9ddb57-4632-4a9f-9afe-1d2e41b94e32  KC Das - Sweet Paradise  2026-01-08
# 2  099deda6-8c53-41cb-abf8-00126e6b2643        Hotel Kadamba Veg  2026-01-22
# 3  94a6ba27-d6ef-4d10-a026-ac0c0afa8505            Cafe Srinidhi  2025-11-10
# 4  216f3ec7-80a9-4d95-872f-715c37163b6d                   Pebble  2025-12-22
#
#    order_value discount_used payment_method
# 0       201.87            No           Card
# 1      1392.27            No           Cash
# 2      1358.35           Yes            UPI
# 3       782.37            No            UPI
# 4      1551.09           Yes            UPI

# %%
df.shape
# Out:
# (25000, 6)

# %%
df.columns
# Out:
# Index(['order_id', 'restaurant_name', 'order_date', 'order_value',
#        'discount_used', 'payment_method'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25000 entries, 0 to 24999
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   order_id         25000 non-null  object
#  1   restaurant_name  25000 non-null  object
#  2   order_date       25000 non-null  object
#  3   order_value      25000 non-null  float64
#  4   discount_used    25000 non-null  object
#  5   payment_method   25000 non-null  object
# dtypes: float64(1), object(5)
# memory usage: 1.1+ MB

# %%
df['order_id']
# Out:
# 0        8174c2af-07a4-4837-9068-1169d963e36e
# 1        0f9ddb57-4632-4a9f-9afe-1d2e41b94e32
# 2        099deda6-8c53-41cb-abf8-00126e6b2643
# 3        94a6ba27-d6ef-4d10-a026-ac0c0afa8505
# 4        216f3ec7-80a9-4d95-872f-715c37163b6d
#                          ...
# 24995    74d3cd31-c1e0-4331-aad7-e1f48b4698ae
# 24996    14db2f6b-f722-44a2-ae55-fe42511e4bb2
# 24997    0fd85321-c1ce-4163-beca-c8ed2b472b8d
# 24998    6b96c699-2d63-4a3c-84f1-5d52ca4bf357
# 24999    af55e28b-27fc-49fc-bdb0-b297999dd152
# Name: order_id, Length: 25000, dtype: object

# %%
df['order_id'].values[0]
# Out:
# '8174c2af-07a4-4837-9068-1169d963e36e'

# %%
df['order_id'].value_counts()
# Out:
# order_id
# af55e28b-27fc-49fc-bdb0-b297999dd152    1
# 8174c2af-07a4-4837-9068-1169d963e36e    1
# 0f9ddb57-4632-4a9f-9afe-1d2e41b94e32    1
# 099deda6-8c53-41cb-abf8-00126e6b2643    1
# 94a6ba27-d6ef-4d10-a026-ac0c0afa8505    1
#                                        ..
# 00a0c73e-b797-4322-afc4-6199d5f68ce9    1
# 11c7ea0f-cafa-4b63-a14e-7129fa934e95    1
# 28bcfd85-fd84-458c-851b-60311c625d01    1
# 25b2d40b-35b3-40f7-9cbe-37bf690db837    1
# e44b23ce-6d29-4c09-9eac-9d4f24f56fd9    1
# Name: count, Length: 25000, dtype: int64

# %%
df['order_id'].isnull().sum()
# Out:
# np.int64(0)

# %%
df.order_id = df.order_id.str.lower()
df.order_id = df.order_id.str.strip()
df.order_id
# Out:
# 0        8174c2af-07a4-4837-9068-1169d963e36e
# 1        0f9ddb57-4632-4a9f-9afe-1d2e41b94e32
# 2        099deda6-8c53-41cb-abf8-00126e6b2643
# 3        94a6ba27-d6ef-4d10-a026-ac0c0afa8505
# 4        216f3ec7-80a9-4d95-872f-715c37163b6d
#                          ...
# 24995    74d3cd31-c1e0-4331-aad7-e1f48b4698ae
# 24996    14db2f6b-f722-44a2-ae55-fe42511e4bb2
# 24997    0fd85321-c1ce-4163-beca-c8ed2b472b8d
# 24998    6b96c699-2d63-4a3c-84f1-5d52ca4bf357
# 24999    af55e28b-27fc-49fc-bdb0-b297999dd152
# Name: order_id, Length: 25000, dtype: object

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.restaurant_name
# Out:
# 0                 TBC Sky Lounge
# 1        KC Das - Sweet Paradise
# 2              Hotel Kadamba Veg
# 3                  Cafe Srinidhi
# 4                         Pebble
#                   ...
# 24995                   Carnatic
# 24996         Reddy's Restaurant
# 24997       BTM Bawarchi Biryani
# 24998                   Nite Out
# 24999                  Zee5 Loft
# Name: restaurant_name, Length: 25000, dtype: object

# %%
df.restaurant_name.values[0]
# Out:
# 'TBC Sky Lounge'

# %%
df.restaurant_name.value_counts()
# Out:
# restaurant_name
# Andhra Grills                              19
# Cake Cafe                                  19
# Hungry Lee                                 18
# Shree Muthahalli Veg                       18
# Orbis Restaurant                           18
#                                            ..
# 24@43 - The Oterra                          1
# Swathi Maharaja                             1
# The Barn - Bar & Kitchen                    1
# The Hub & The Bar - Hotel Ramada Encore     1
# Kamat Bugle Rock                            1
# Name: count, Length: 3159, dtype: int64

# %%
df['restaurant_name'] = df['restaurant_name'].str.replace(r'[^a-zA-Z0-9 ]', '', regex=True)

# %%
df.restaurant_name.isnull().sum()
# Out:
# np.int64(0)

# %%
df.restaurant_name = df.restaurant_name.str.lower()
df.restaurant_name = df.restaurant_name.str.strip()
df.restaurant_name
# Out:
# 0                tbc sky lounge
# 1        kc das  sweet paradise
# 2             hotel kadamba veg
# 3                 cafe srinidhi
# 4                        pebble
#                   ...
# 24995                  carnatic
# 24996         reddys restaurant
# 24997      btm bawarchi biryani
# 24998                  nite out
# 24999                 zee5 loft
# Name: restaurant_name, Length: 25000, dtype: object

# %%
df.order_date
# Out:
# 0        2025-05-06
# 1        2026-01-08
# 2        2026-01-22
# 3        2025-11-10
# 4        2025-12-22
#             ...
# 24995    2025-11-24
# 24996    2025-06-24
# 24997    2025-12-04
# 24998    2025-09-21
# 24999    2025-08-07
# Name: order_date, Length: 25000, dtype: object

# %%
df.order_date.values[0]
# Out:
# '2025-05-06'

# %%
import datetime

# %%
df.order_date = pd.to_datetime(df.order_date, format="%Y-%m-%d")

# %%
df.order_date.isnull().sum()
# Out:
# np.int64(0)

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25000 entries, 0 to 24999
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   order_id         25000 non-null  object
#  1   restaurant_name  25000 non-null  object
#  2   order_date       25000 non-null  datetime64[ns]
#  3   order_value      25000 non-null  float64
#  4   discount_used    25000 non-null  object
#  5   payment_method   25000 non-null  object
# dtypes: datetime64[ns](1), float64(1), object(4)
# memory usage: 1.1+ MB
# None

# %%
df.order_value
# Out:
# 0         201.87
# 1        1392.27
# 2        1358.35
# 3         782.37
# 4        1551.09
#           ...
# 24995    1254.91
# 24996     760.39
# 24997     707.99
# 24998     724.29
# 24999     905.00
# Name: order_value, Length: 25000, dtype: float64

# %%
df.order_value = df.order_value.astype(int)

# %%
df.order_value.value_counts()
# Out:
# order_value
# 1229    32
# 585     30
# 381     30
# 1377    29
# 784     29
#         ..
# 1942     2
# 1552     2
# 177      2
# 1605     2
# 1570     1
# Name: count, Length: 1850, dtype: int64

# %%
df.order_value.isnull().sum()
# Out:
# np.int64(0)

# %%
df.order_value.describe()
# Out:
# count    25000.000000
# mean       985.585320
# std        472.950179
# min        150.000000
# 25%        589.000000
# 50%        966.000000
# 75%       1344.000000
# max       1999.000000
# Name: order_value, dtype: float64

# %%
df.discount_used
# Out:
# 0         No
# 1         No
# 2        Yes
# 3         No
# 4        Yes
#         ...
# 24995     No
# 24996     No
# 24997    Yes
# 24998    Yes
# 24999     No
# Name: discount_used, Length: 25000, dtype: object

# %%
df.discount_used.value_counts()
# Out:
# discount_used
# No     12509
# Yes    12491
# Name: count, dtype: int64

# %%
df.discount_used = df.discount_used.str.lower()
df.discount_used = df.discount_used.str.strip()
df.discount_used
# Out:
# 0         no
# 1         no
# 2        yes
# 3         no
# 4        yes
#         ...
# 24995     no
# 24996     no
# 24997    yes
# 24998    yes
# 24999     no
# Name: discount_used, Length: 25000, dtype: object

# %%
df.discount_used.isnull().sum()
# Out:
# np.int64(0)

# %%
df.payment_method
# Out:
# 0        Card
# 1        Cash
# 2         UPI
# 3         UPI
# 4         UPI
#          ...
# 24995     UPI
# 24996    Card
# 24997    Card
# 24998    Card
# 24999     UPI
# Name: payment_method, Length: 25000, dtype: object

# %%
df.payment_method.value_counts()
# Out:
# payment_method
# Cash    8384
# Card    8364
# UPI     8252
# Name: count, dtype: int64

# %%
df['payment_method'] = df['payment_method'].str.lower()
df['payment_method'] = df['payment_method'].str.strip()
df['payment_method']
# Out:
# 0        card
# 1        cash
# 2         upi
# 3         upi
# 4         upi
#          ...
# 24995     upi
# 24996    card
# 24997    card
# 24998    card
# 24999     upi
# Name: payment_method, Length: 25000, dtype: object

# %%
df.payment_method.isnull().sum()
# Out:
# np.int64(0)

# %%
df = df.drop_duplicates(subset=['order_id'])

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.shape
# Out:
# (25000, 6)

# %%
df.head()
# Out:
#                                order_id         restaurant_name order_date  \
# 0  8174c2af-07a4-4837-9068-1169d963e36e          tbc sky lounge 2025-05-06
# 1  0f9ddb57-4632-4a9f-9afe-1d2e41b94e32  kc das  sweet paradise 2026-01-08
# 2  099deda6-8c53-41cb-abf8-00126e6b2643       hotel kadamba veg 2026-01-22
# 3  94a6ba27-d6ef-4d10-a026-ac0c0afa8505           cafe srinidhi 2025-11-10
# 4  216f3ec7-80a9-4d95-872f-715c37163b6d                  pebble 2025-12-22
#
#    order_value discount_used payment_method
# 0          201            no           card
# 1         1392            no           cash
# 2         1358           yes            upi
# 3          782            no            upi
# 4         1551           yes            upi

# %%
Order_data = df.to_csv('Order_data.csv', index= False)
